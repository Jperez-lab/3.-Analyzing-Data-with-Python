# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests 
import html5lib
import random
import pandas as pd# this module helps us to download a web page
website= "https://origin.cpc.ncep.noaa.gov/products/analysis_monitoring/ensostuff/ONI_v5.php"
result= requests.get(website)
content = result.text
soup = BeautifulSoup(content, "html.parser")
tables = soup.find_all('table')
len(tables)
# Out:
# 11

# %%
ENOS= pd.read_html(str(tables[3]), flavor='bs4')[0]
ENOS
# Out:
#                                                    0   \
# 0   Search the CPC About Us  Our Mission  Who We A...
# 1                                      Search the CPC
# 2   About Us  Our Mission  Who We Are Contact Us  ...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 92                                               2019
# 93                                               Year
# 94                                               2020
# 95                                               2021
# 96                                               2022
#
#                                                    1     2     3     4     5   \
# 0   HOME >  Climate & Weather Linkage >  El Niño /...   NaN   NaN   NaN   NaN
# 1                                                 NaN   NaN   NaN   NaN   NaN
# 2                                                 NaN   NaN   NaN   NaN   NaN
# 3                                                 NaN   NaN   NaN   NaN   NaN
# 4                                                 NaN   NaN   NaN   NaN   NaN
# ..                                                ...   ...   ...   ...   ...
# 92                                                0.7   0.7   0.7   0.7   0.5
# 93                                                DJF   JFM   FMA   MAM   AMJ
# 94                                                0.5   0.5   0.4   0.2  -0.1
# 95                                               -1.0  -0.9  -0.8  -0.7  -0.5
# 96                                               -1.0  -0.9  -1.0  -1.1  -1.0
#
#       6     7     8     9     10    11    12
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ...   ...   ...   ...   ...   ...   ...
# 92   0.5   0.3   0.1   0.2   0.3   0.5   0.5
# 93   MJJ   JJA   JAS   ASO   SON   OND   NDJ
# 94  -0.3  -0.4  -0.6  -0.9  -1.2  -1.3  -1.2
# 95  -0.4  -0.4  -0.5  -0.7  -0.8  -1.0  -1.0
# 96  -0.9  -0.8  -0.9   NaN   NaN   NaN   NaN
#
# [97 rows x 13 columns]
